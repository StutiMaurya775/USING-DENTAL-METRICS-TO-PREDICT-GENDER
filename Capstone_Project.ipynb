# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, Normalizer
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, classification_report
from sklearn.model_selection import train_test_split  # Import train_test_split

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, Normalizer
from sklearn.model_selection import train_test_split # Import train_test_split from the correct module
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, classification_report

# ... (rest of your code remains the same) ...

# Original import:
# from sklearn.preprocessing import LabelEncoder, Normalizer, train_test_split

# Correct import:
from sklearn.preprocessing import LabelEncoder, Normalizer
from sklearn.model_selection import train_test_split # Import train_test_split from the correct module

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, Normalizer
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn import metrics # needs more code to be correct


# Step 1: Load the dataset
data = pd.read_csv("Dentistry Dataset.csv")

# Step 2: Initial inspection
print("Dataset Head:\n", data.head())
print("\nDataset Info:\n")
data.info()
print("\nMissing Values:\n", data.isnull().sum())

# Step 3: Handle missing values (example: filling missing with mean for numeric columns)
# Select only numeric columns for mean calculation
numeric_cols = data.select_dtypes(include=np.number).columns
data[numeric_cols] = data[numeric_cols].fillna(data[numeric_cols].mean())

# Select only numeric columns for mean calculation
numeric_cols = data.select_dtypes(include=np.number).columns
data[numeric_cols] = data[numeric_cols].fillna(data[numeric_cols].mean())

# For categorical columns, fill missing values with the mode
for col in data.select_dtypes(include=['object']).columns:
    data[col].fillna(data[col].mode()[0], inplace=True)

# Step 4: Encoding categorical data (if applicable)
if 'Gender' in data.columns:
    le = LabelEncoder()
    data['Gender'] = le.fit_transform(data['Gender'])  # 0 for Female, 1 for Male

# Step 5: Split data into independent (X) and dependent (y) variables
X = data.drop(columns=['Gender', 'SampleID', 'SL No.'], errors='ignore')  # Exclude target and IDs
y = data['Gender']

# Impute remaining NaNs (if any) with the mean of each column
# This step is added to ensure all NaNs are handled before normalization
for col in X.select_dtypes(include=[np.number]).columns:
    X[col].fillna(X[col].mean(), inplace=True)



# ... (rest of your code remains the same) ...
# Out:
# Dataset Head:
#     Sl No  Sample ID  Age  Gender  inter canine distance intraoral  \
# 0      1        NaN   24  Female                            25.06
# 1      2        NaN   22  Female                            25.78
# 2      3        NaN   23  Female                            23.83
# 3      4        NaN   20  Female                            26.12
# 4      5        NaN   20  Female                            26.36
#
#    intercanine distance casts  right canine width intraoral  \
# 0                       25.05                          6.08
# 1                       25.79                          6.13
# 2                       23.83                          5.91
# 3                       26.12                          6.08
# 4                       26.41                          6.09
#
#    right canine width casts  left canine width intraoral  \
# 0                      6.08                         6.09
# 1                      6.13                         6.33
# ...
